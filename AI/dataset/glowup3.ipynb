# %%
import pandas as pd
dataset = pd.read_csv("./glowup_cleaned.csv")

# %%
dataset['notable_effects'].isna().sum()
# Out:
# np.int64(0)

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0         0
# product_name       0
# product_type       0
# brand              0
# notable_effects    0
# skin_type          0
# price              0
# picture_src        0
# description        0
# rating             0
# dtype: int64

# %%
len(dataset)
# Out:
# 678

# %%
type(dataset)
# Out:
# pandas.DataFrame

# %%
for index,row in dataset.iterrows():
   print(type(row['notable_effects'])) 
   print(type(row['skin_type']))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ...

# %%
is_all_list = dataset['notable_effects'].apply(lambda x: isinstance(x, list)).all()

print(f"Is the whole column a list? {is_all_list}")
is_all_list = dataset['skin_type'].apply(lambda x: isinstance(x, list)).all()

print(f"Is the whole column a list? {is_all_list}")
# Out:
# Is the whole column a list? True
# Is the whole column a list? True

# %%
dataset.to_csv("glowup.csv")

# %%
import ast
dataset['notable_effects'] = dataset['notable_effects'].map(ast.literal_eval)
dataset['skin_type']= dataset['skin_type'].map(ast.literal_eval)

# %%
import pandas as pd
dataset= pd.read_csv("./glowup.csv")
type(dataset['notable_effects'][0])
# Out:
# str
